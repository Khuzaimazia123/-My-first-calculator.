# %%
first_number=int(input("Enter first number: "))
print (first_number)
operator=(input("Enter operator (,+,-,*,/,) : "))
print (operator)
second_number=int(input("Enter second number: "))
result=first_number*
second_number
print (result)
# Out:
# Enter first number: 458902
# 458902
# Enter operator (,+,-,*,/,) : *
# *
# Enter second number: 2681
# 456221
